# %% [markdown]
# <a href="https://colab.research.google.com/github/Mollylst/DeepFake-Project/blob/main/generate_fake_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive//My Drive/"
# Out:
#  celeb			 PCA-y-dct.npy	        test-labels-ffhq.npy
# 'Colab Notebooks'	 Resnet18-CelebA.pth    train-images-ffhq.npy
#  densenet-FFHQ.pth	 Resnet18-FFHQ.pth      train-labels-ffhq.npy
# 'FFHQ data 8:1:1'	 Resnet34-CelebA.pth    valid-images-ffhq.npy
#  my_checkpoint.pth.tar	 Resnet34-FFHQ.pth      valid-labels-ffhq.npy
#  PCA-X-dct.npy		 test-images-ffhq.npy   vgg-FFHQ.pth

# %%
import os
path="/content/drive/MyDrive/Colab Notebooks/stylegan-master"
os.chdir(path)
os.listdir(path)
# Out:
# ['config.py',
#  'dataset_tool.py',
#  'LICENSE.txt',
#  'README.md',
#  'run_metrics.py',
#  'generate_figures.py',
#  'stylegan-teaser.png',
#  'train.py',
#  'metrics',
#  'dnnlib',
#  'training',
#  '__pycache__',
#  'cache',
#  'karras2019stylegan-ffhq-1024x1024.pkl',
#  'results',
#  'karras2019stylegan-celebahq-1024x1024.pkl',
#  'pretrained_example.py']

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# Generate 10000 FFHQ-StyleGAN2 images

# %%
# !python run_generator.py generate-images --network=gdrive:networks/stylegan2-ffhq-config-f.pkl\
  --seeds=0-9999 --truncation-psi=1.0
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Generating image for seed 5001 (5001/10000) ...
# Generating image for seed 5002 (5002/10000) ...
# Generating image for seed 5003 (5003/10000) ...
# Generating image for seed 5004 (5004/10000) ...
# Generating image for seed 5005 (5005/10000) ...
# Generating image for seed 5006 (5006/10000) ...
# Generating image for seed 5007 (5007/10000) ...
# Generating image for seed 5008 (5008/10000) ...
# Generating image for seed 5009 (5009/10000) ...
# Generating image for seed 5010 (5010/10000) ...
# Generating image for seed 5011 (5011/10000) ...
# Generating image for seed 5012 (5012/10000) ...
# Generating image for seed 5013 (5013/10000) ...
# Generating image for seed 5014 (5014/10000) ...
# Generating image for seed 5015 (5015/10000) ...
# Generating image for seed 5016 (5016/10000) ...
# Generating image for seed 5017 (5017/10000) ...
# Generating image for seed 5018 (5018/10000) ...
# Generating image for seed 5019 (5019/10000) ...
# ...

# %% [markdown]
# Generate 10000 FFHQ-StyleGAN fake images

# %%
# !python pretrained_example.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/stylegan-master/dnnlib/tflib/tfutil.py:34: The name tf.Dimension is deprecated. Please use tf.compat.v1.Dimension instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/stylegan-master/dnnlib/tflib/tfutil.py:74: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/stylegan-master/dnnlib/tflib/tfutil.py:128: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/stylegan-master/dnnlib/tflib/tfutil.py:97: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/stylegan-master/dnnlib/tflib/tfutil.py:109: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# ...
