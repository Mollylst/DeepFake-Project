# %% [markdown]
# <a href="https://colab.research.google.com/github/Mollylst/DeepFake-Project/blob/main/DCT_FFHQ_Stylegan_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -uq '/content/drive/MyDrive/FFHQ data 8:1:1/train-fake-stylegan1.zip' -d /content/train
# !unzip -uq '/content/drive/MyDrive/FFHQ data 8:1:1/train_real.zip' -d /content/train
# !unzip -uq '/content/drive/MyDrive/FFHQ data 8:1:1/test-fake-stylegan1.zip' -d /content/test
# !unzip -uq '/content/drive/MyDrive/FFHQ data 8:1:1/test_real.zip' -d /content/test

# %%
# !rm -rf my_che test

# %%
import numpy as np
from PIL import Image
from scipy import fftpack

def dct2(array):
    array = fftpack.dct(array, type=2, norm="ortho", axis=0)
    array = fftpack.dct(array, type=2, norm="ortho", axis=1)
    return array

def log_scale(array, epsilon=1e-12):
    """Log scale the input array.
    """
    array = np.abs(array)
    array += epsilon  # no zero in log
    array = np.log(array)
    return array

# %%
import cv2
import os
import numpy as np
import random
import torch
import torchvision
import os
from torchvision import datasets 
from torch.utils.data import random_split
import torchvision.transforms as transforms

def image2npy(label2idx, dir_path='/content/train'):
    i = 0
    data = []
    for (root, dirs, files) in os.walk(dir_path):
        for file in files: 
            img_path = os.path.join(root, file) 
            File = root.split('/')[-1] #name of the file which is label
            image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            image = np.asarray(image)
            image = dct2(image)
            image = log_scale(image)

            label = label2idx[File]
            data.append([np.asarray(image), label])
    return data

# %%
label2idx = {'fake':1, 'real': 0}
data = image2npy(label2idx, dir_path='/content/train')

train_data,valid_data = random_split(data,[16000,2000])

X_train = np.array([i[0] for i in train_data]) # train feature
X_train_max = X_train.max(0)
X_train = X_train/X_train_max
y_train = np.array([i[1] for i in train_data]) # train label

X_valid = np.array([i[0] for i in valid_data]) 
X_valid_max = X_valid.max(0)
X_valid = X_valid/X_valid_max
y_valid = np.array([i[1] for i in valid_data]) 
print(len(X_train), len(y_train), len(X_valid), len(y_valid))

np.save('drive/MyDrive/train-images-ffhq-stylegan.npy', X_train)
np.save('drive/MyDrive/train-labels-ffhq-stylegan.npy', y_train)
np.save('drive/MyDrive/valid-images-ffhq-stylegan.npy', X_valid)
np.save('drive/MyDrive/valid-labels-ffhq-stylegan.npy', y_valid)

data = image2npy(label2idx, dir_path='/content/test')

X_test = np.array([i[0] for i in data]) # test feature
X_test_max = X_test.max(0)
X_test = X_test/X_test_max
y_test = np.array([i[1] for i in data]) # test label 
print(len(X_test), len(y_test))

np.save('drive/MyDrive/test-images-ffhq-stylegan.npy', X_test)
np.save('drive/MyDrive/test-labels-ffhq-stylegan.npy', y_test)
# Out:
# 16000 16000 2000 2000
# 2000 2000

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(8,8))
axes[0].imshow(X_train[y_train==label2idx['fake']].mean(0),cmap='rainbow',interpolation='none')
axes[0].set_title('fake')
axes[1].imshow(X_train[y_train==label2idx['real']].mean(0),cmap='rainbow',interpolation='none')
axes[1].set_title('real')
axes[2].imshow(X_train[y_train==label2idx['fake']].mean(0)-X_train[y_train==label2idx['real']].mean(0),cmap='rainbow',interpolation='none')
axes[2].set_title('difference')
# Out:
# Text(0.5, 1.0, 'difference')

# %%
import torch
import torchvision
import numpy as np
from torchvision import datasets 

train_images = np.load('./drive/MyDrive/train-images-ffhq-stylegan.npy')
train_labels = np.load('./drive/MyDrive/train-labels-ffhq-stylegan.npy')
valid_images = np.load('./drive/MyDrive/valid-images-ffhq-stylegan.npy')
valid_labels = np.load('./drive/MyDrive/valid-labels-ffhq-stylegan.npy')
test_images = np.load('./drive/MyDrive/test-images-ffhq-stylegan.npy')
test_labels = np.load('./drive/MyDrive/test-labels-ffhq-stylegan.npy')

X_train = torch.from_numpy(train_images).float() 
X_valid = torch.from_numpy(valid_images).float()
X_test = torch.from_numpy(test_images).float()
Y_train = torch.from_numpy(train_labels).long() 
Y_valid = torch.from_numpy(valid_labels).long()
Y_test = torch.from_numpy(test_labels).long()

print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_test.shape, Y_test.shape)

MINIBATCH_SIZE = 128

trainDataset = torch.utils.data.TensorDataset(X_train, Y_train) 
trainloader = torch.utils.data.DataLoader(
    dataset=trainDataset,
    batch_size=MINIBATCH_SIZE,
    shuffle=True,
    num_workers=2          # set multi-work num read data
)

image, label = iter(trainloader).next()
print(type(image), type(label))
print(image.size(), label.size())

validDataset = torch.utils.data.TensorDataset(X_valid, Y_valid) 
validloader = torch.utils.data.DataLoader(
    dataset=validDataset,
    batch_size=MINIBATCH_SIZE,
    shuffle=False,
    num_workers=2          # set multi-work num read data
)

testDataset = torch.utils.data.TensorDataset(X_test, Y_test) 
testloader = torch.utils.data.DataLoader(
    dataset=testDataset,
    batch_size=MINIBATCH_SIZE, 
    shuffle=False, 
    num_workers=2 
)
# Out:
# torch.Size([16000, 128, 128]) torch.Size([16000])
# torch.Size([2000, 128, 128]) torch.Size([2000])
# torch.Size([2000, 128, 128]) torch.Size([2000])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([128, 128, 128]) torch.Size([128])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
import torch.nn as nn
input_size=16384
num_classes=2

class LogisticRegression(nn.Module):
    def __init__(self, input_size, num_classes):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, num_classes)

    def forward(self, x):
        out = self.linear(x)
        return torch.sigmoid(out)
        #return out
 
net = LogisticRegression(input_size, num_classes).to(device)

# %%
import torch.optim as optim
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import CosineAnnealingLR

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001,momentum=0.9, weight_decay=5e-4) 
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0, last_epoch=-1, verbose=False)

# %%
import time
import matplotlib.pyplot as plt

num_epoch=50
path='./deepfake-LR.pth'

def train_and_valid():
    history = []
    best_acc = 0.0
    best_epoch = 0
    
    for epoch in range(0,num_epoch):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, num_epoch))

        net.train()
        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0

        #train
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.reshape(-1, 128*128).to(device)
            labels = labels.to(device)  # Labels
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs,labels)

            #L1_reg = 0
            #for param in model.parameters():
              #L1_reg += torch.sum(torch.abs(param))
            #loss += 0.001 * L1_reg  # lambda=0.001
            
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * inputs.size(0)
            _,predictions = torch.max(outputs.data, 1)
            train_acc += (predictions == labels).sum().item()

        #valid
        net.eval()
        with torch.no_grad():

            for j, (inputs, labels) in enumerate(validloader):

                inputs = inputs.reshape(-1, 128*128).to(device)
                labels = labels.to(device)  # Labels
                outputs = net(inputs)
                loss = criterion(outputs, labels)
                valid_loss += loss.item() * inputs.size(0)
                _,predictions = torch.max(outputs.data, 1)
                valid_acc += (predictions == labels).sum().item()
 
        avg_train_loss = train_loss/ len(trainDataset)
        avg_train_acc = train_acc/ len(trainDataset)
 
        avg_valid_loss = valid_loss/ len(validDataset)
        avg_valid_acc = valid_acc/ len(validDataset)

        #record the accuracy and loss in each epoch
        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
 
        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1
            torch.save(net.state_dict(),path)
        scheduler.step()  

        epoch_end = time.time()
        
        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))

    return history
    
#start training and testing
history = train_and_valid()

#make the plots
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 2)
#plt.savefig(dataset+'_loss_curve.png')
plt.show()
 
plt.plot(history[:, 2:4])
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1.1)
#plt.savefig(dataset+'_accuracy_curve.png')
plt.show()
# Out:
# Epoch: 1/50
# Epoch: 001, Training: Loss: 0.6900, Accuracy: 53.6000%,
# 		Validation: Loss: 0.6923, Accuracy: 49.2000%, Time: 1.5872s
# Best Accuracy for validation : 0.4920 at epoch 001
# Epoch: 2/50
# Epoch: 002, Training: Loss: 0.6785, Accuracy: 60.1875%,
# 		Validation: Loss: 0.6756, Accuracy: 61.9500%, Time: 1.4927s
# Best Accuracy for validation : 0.6195 at epoch 002
# Epoch: 3/50
# Epoch: 003, Training: Loss: 0.6676, Accuracy: 65.0750%,
# 		Validation: Loss: 0.6656, Accuracy: 61.8000%, Time: 1.4886s
# Best Accuracy for validation : 0.6195 at epoch 002
# Epoch: 4/50
# Epoch: 004, Training: Loss: 0.6576, Accuracy: 72.1500%,
# 		Validation: Loss: 0.6572, Accuracy: 69.0500%, Time: 1.4895s
# Best Accuracy for validation : 0.6905 at epoch 004
# Epoch: 5/50
# Epoch: 005, Training: Loss: 0.6490, Accuracy: 74.6250%,
# 		Validation: Loss: 0.6499, Accuracy: 70.8000%, Time: 1.4861s
# Best Accuracy for validation : 0.7080 at epoch 005
# Epoch: 6/50
# Epoch: 006, Training: Loss: 0.6396, Accuracy: 78.0187%,
# 		Validation: Loss: 0.6438, Accuracy: 68.8500%, Time: 1.4805s
# Best Accuracy for validation : 0.7080 at epoch 005
# Epoch: 7/50
# Epoch: 007, Training: Loss: 0.6311, Accuracy: 79.7313%,
# 		Validation: Loss: 0.6372, Accuracy: 75.5000%, Time: 1.4840s
# Best Accuracy for validation : 0.7550 at epoch 007
# Epoch: 8/50
# Epoch: 008, Training: Loss: 0.6234, Accuracy: 81.0312%,
# 		Validation: Loss: 0.6325, Accuracy: 76.3500%, Time: 1.5027s
# Best Accuracy for validation : 0.7635 at epoch 008
# Epoch: 9/50
# Epoch: 009, Training: Loss: 0.6155, Accuracy: 83.8438%,
# 		Validation: Loss: 0.6263, Accuracy: 77.5000%, Time: 1.4800s
# Best Accuracy for validation : 0.7750 at epoch 009
# Epoch: 10/50
# Epoch: 010, Training: Loss: 0.6109, Accuracy: 81.7062%,
# 		Validation: Loss: 0.6201, Accuracy: 77.9000%, Time: 1.4937s
# Best Accuracy for validation : 0.7790 at epoch 010
# Epoch: 11/50
# Epoch: 011, Training: Loss: 0.6021, Accuracy: 85.2812%,
# 		Validation: Loss: 0.6156, Accuracy: 78.3500%, Time: 1.4854s
# Best Accuracy for validation : 0.7835 at epoch 011
# Epoch: 12/50
# Epoch: 012, Training: Loss: 0.5960, Accuracy: 86.5688%,
# 		Validation: Loss: 0.6113, Accuracy: 79.2500%, Time: 1.4901s
# Best Accuracy for validation : 0.7925 at epoch 012
# Epoch: 13/50
# Epoch: 013, Training: Loss: 0.5905, Accuracy: 86.9375%,
# 		Validation: Loss: 0.6067, Accuracy: 78.9500%, Time: 1.4895s
# Best Accuracy for validation : 0.7925 at epoch 012
# Epoch: 14/50
# Epoch: 014, Training: Loss: 0.5857, Accuracy: 86.1625%,
# 		Validation: Loss: 0.6030, Accuracy: 78.8500%, Time: 1.4826s
# Best Accuracy for validation : 0.7925 at epoch 012
# Epoch: 15/50
# Epoch: 015, Training: Loss: 0.5803, Accuracy: 87.1313%,
# 		Validation: Loss: 0.6051, Accuracy: 76.7000%, Time: 1.4974s
# Best Accuracy for validation : 0.7925 at epoch 012
# Epoch: 16/50
# Epoch: 016, Training: Loss: 0.5762, Accuracy: 86.8313%,
# 		Validation: Loss: 0.5978, Accuracy: 79.5500%, Time: 1.5025s
# Best Accuracy for validation : 0.7955 at epoch 016
# Epoch: 17/50
# Epoch: 017, Training: Loss: 0.5713, Accuracy: 87.5250%,
# 		Validation: Loss: 0.5928, Accuracy: 79.9500%, Time: 1.4576s
# Best Accuracy for validation : 0.7995 at epoch 017
# Epoch: 18/50
# Epoch: 018, Training: Loss: 0.5671, Accuracy: 88.1125%,
# 		Validation: Loss: 0.5929, Accuracy: 79.4500%, Time: 1.4648s
# Best Accuracy for validation : 0.7995 at epoch 017
# Epoch: 19/50
# Epoch: 019, Training: Loss: 0.5624, Accuracy: 88.7312%,
# 		Validation: Loss: 0.5873, Accuracy: 80.5500%, Time: 1.4416s
# Best Accuracy for validation : 0.8055 at epoch 019
# Epoch: 20/50
# Epoch: 020, Training: Loss: 0.5593, Accuracy: 88.9250%,
# 		Validation: Loss: 0.5844, Accuracy: 80.6000%, Time: 1.4592s
# Best Accuracy for validation : 0.8060 at epoch 020
# Epoch: 21/50
# Epoch: 021, Training: Loss: 0.5550, Accuracy: 89.4000%,
# 		Validation: Loss: 0.5820, Accuracy: 80.5000%, Time: 1.4745s
# Best Accuracy for validation : 0.8060 at epoch 020
# Epoch: 22/50
# Epoch: 022, Training: Loss: 0.5513, Accuracy: 89.5938%,
# 		Validation: Loss: 0.5809, Accuracy: 80.7500%, Time: 1.4615s
# Best Accuracy for validation : 0.8075 at epoch 022
# Epoch: 23/50
# Epoch: 023, Training: Loss: 0.5483, Accuracy: 89.5438%,
# 		Validation: Loss: 0.5778, Accuracy: 80.8000%, Time: 1.4851s
# Best Accuracy for validation : 0.8080 at epoch 023
# Epoch: 24/50
# Epoch: 024, Training: Loss: 0.5456, Accuracy: 89.6750%,
# 		Validation: Loss: 0.5760, Accuracy: 81.2000%, Time: 1.5450s
# Best Accuracy for validation : 0.8120 at epoch 024
# Epoch: 25/50
# Epoch: 025, Training: Loss: 0.5423, Accuracy: 89.9813%,
# 		Validation: Loss: 0.5739, Accuracy: 81.1000%, Time: 1.5697s
# Best Accuracy for validation : 0.8120 at epoch 024
# Epoch: 26/50
# Epoch: 026, Training: Loss: 0.5396, Accuracy: 89.8875%,
# 		Validation: Loss: 0.5716, Accuracy: 80.9000%, Time: 1.5687s
# Best Accuracy for validation : 0.8120 at epoch 024
# Epoch: 27/50
# Epoch: 027, Training: Loss: 0.5367, Accuracy: 90.3937%,
# 		Validation: Loss: 0.5710, Accuracy: 80.3500%, Time: 1.5739s
# Best Accuracy for validation : 0.8120 at epoch 024
# Epoch: 28/50
# Epoch: 028, Training: Loss: 0.5348, Accuracy: 90.1813%,
# 		Validation: Loss: 0.5689, Accuracy: 81.6000%, Time: 1.5549s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 29/50
# Epoch: 029, Training: Loss: 0.5318, Accuracy: 90.4813%,
# 		Validation: Loss: 0.5668, Accuracy: 81.3500%, Time: 1.5673s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 30/50
# Epoch: 030, Training: Loss: 0.5298, Accuracy: 90.4188%,
# 		Validation: Loss: 0.5652, Accuracy: 80.8500%, Time: 1.5616s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 31/50
# Epoch: 031, Training: Loss: 0.5274, Accuracy: 90.7563%,
# 		Validation: Loss: 0.5649, Accuracy: 81.6000%, Time: 1.5712s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 32/50
# Epoch: 032, Training: Loss: 0.5256, Accuracy: 90.6875%,
# 		Validation: Loss: 0.5625, Accuracy: 81.5000%, Time: 1.5357s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 33/50
# Epoch: 033, Training: Loss: 0.5233, Accuracy: 90.7062%,
# 		Validation: Loss: 0.5614, Accuracy: 81.4500%, Time: 1.5442s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 34/50
# Epoch: 034, Training: Loss: 0.5218, Accuracy: 90.8937%,
# 		Validation: Loss: 0.5600, Accuracy: 81.3500%, Time: 1.5473s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 35/50
# Epoch: 035, Training: Loss: 0.5196, Accuracy: 91.0750%,
# 		Validation: Loss: 0.5588, Accuracy: 81.2000%, Time: 1.5683s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 36/50
# Epoch: 036, Training: Loss: 0.5176, Accuracy: 91.1875%,
# 		Validation: Loss: 0.5578, Accuracy: 81.2500%, Time: 1.5666s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 37/50
# Epoch: 037, Training: Loss: 0.5161, Accuracy: 91.3500%,
# 		Validation: Loss: 0.5570, Accuracy: 81.2500%, Time: 1.5748s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 38/50
# Epoch: 038, Training: Loss: 0.5145, Accuracy: 91.3438%,
# 		Validation: Loss: 0.5558, Accuracy: 81.4000%, Time: 1.5638s
# Best Accuracy for validation : 0.8160 at epoch 028
# Epoch: 39/50
# Epoch: 039, Training: Loss: 0.5130, Accuracy: 91.4562%,
# 		Validation: Loss: 0.5550, Accuracy: 81.8000%, Time: 1.5096s
# Best Accuracy for validation : 0.8180 at epoch 039
# Epoch: 40/50
# Epoch: 040, Training: Loss: 0.5115, Accuracy: 91.3438%,
# 		Validation: Loss: 0.5544, Accuracy: 82.0000%, Time: 1.4973s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 41/50
# Epoch: 041, Training: Loss: 0.5101, Accuracy: 91.5312%,
# 		Validation: Loss: 0.5532, Accuracy: 81.6000%, Time: 1.5038s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 42/50
# Epoch: 042, Training: Loss: 0.5086, Accuracy: 91.8063%,
# 		Validation: Loss: 0.5525, Accuracy: 81.4000%, Time: 1.5134s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 43/50
# Epoch: 043, Training: Loss: 0.5074, Accuracy: 91.8250%,
# 		Validation: Loss: 0.5520, Accuracy: 82.0000%, Time: 1.4817s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 44/50
# Epoch: 044, Training: Loss: 0.5063, Accuracy: 91.7125%,
# 		Validation: Loss: 0.5511, Accuracy: 81.3500%, Time: 1.4918s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 45/50
# Epoch: 045, Training: Loss: 0.5050, Accuracy: 91.9312%,
# 		Validation: Loss: 0.5501, Accuracy: 81.5000%, Time: 1.4835s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 46/50
# Epoch: 046, Training: Loss: 0.5038, Accuracy: 91.9438%,
# 		Validation: Loss: 0.5512, Accuracy: 81.6500%, Time: 1.4529s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 47/50
# Epoch: 047, Training: Loss: 0.5031, Accuracy: 91.9312%,
# 		Validation: Loss: 0.5500, Accuracy: 80.6000%, Time: 1.4660s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 48/50
# Epoch: 048, Training: Loss: 0.5018, Accuracy: 92.0250%,
# 		Validation: Loss: 0.5501, Accuracy: 80.6500%, Time: 1.5113s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 49/50
# Epoch: 049, Training: Loss: 0.5009, Accuracy: 91.9875%,
# 		Validation: Loss: 0.5479, Accuracy: 81.4000%, Time: 1.4799s
# Best Accuracy for validation : 0.8200 at epoch 040
# Epoch: 50/50
# Epoch: 050, Training: Loss: 0.4999, Accuracy: 92.2250%,
# 		Validation: Loss: 0.5473, Accuracy: 82.1500%, Time: 1.4758s
# Best Accuracy for validation : 0.8215 at epoch 050

# %%
net.load_state_dict(torch.load(path))
correct = 0
total = 0
net.eval()
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        inputs, labels = data
        inputs = inputs.reshape(-1, 128*128).to(device)
        labels = labels.to(device)
        #inputs, labels = inputs.to(device), labels.to(device)

        outputs = net(inputs)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 82 %
